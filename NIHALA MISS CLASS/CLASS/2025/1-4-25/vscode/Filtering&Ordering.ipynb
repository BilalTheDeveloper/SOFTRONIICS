# %%
import pandas as pd

# %%
df = pd.read_csv("world_population.csv")

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.head(100)
# Out:
#     Rank CCA3         Country           Capital Continent  2022 Population  \
# 0     36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1    138  ALB         Albania            Tirana    Europe        2842321.0
# 2     34  DZA         Algeria           Algiers    Africa       44903225.0
# 3    213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4    203  AND         Andorra  Andorra la Vella    Europe          79824.0
# ..   ...  ...             ...               ...       ...              ...
# 95    35  IRQ            Iraq           Baghdad      Asia       44496122.0
# 96   125  IRL         Ireland            Dublin    Europe        5023109.0
# 97   202  IMN     Isle of Man           Douglas    Europe          84519.0
# 98    98  ISR          Israel         Jerusalem      Asia        9038309.0
# 99    25  ITA           Italy              Rome    Europe       59037474.0
#
# ...

# %%
df[df["Rank"]>=200]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 3     213  ASM                American Samoa         Pago Pago        Oceania
# 4     203  AND                       Andorra  Andorra la Vella         Europe
# 6     224  AIA                      Anguilla        The Valley  North America
# 7     201  ATG           Antigua and Barbuda      Saint John’s  North America
# 22    206  BMU                       Bermuda          Hamilton  North America
# 28    221  VGB        British Virgin Islands         Road Town  North America
# 37    205  CYM                Cayman Islands       George Town  North America
# 44    223  COK                  Cook Islands            Avarua        Oceania
# 53    204  DMA                      Dominica            Roseau  North America
# 64    231  FLK              Falkland Islands           Stanley  South America
# 65    209  FRO                 Faroe Islands          Tórshavn         Europe
# ...

# %%
pd.options.display.max_rows = 99

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia       41128771.0
# 1   138  ALB         Albania            Tirana    Europe        2842321.0
# 2    34  DZA         Algeria           Algiers    Africa       44903225.0
# 3   213  ASM  American Samoa         Pago Pago   Oceania          44273.0
# 4   203  AND         Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 2       43451666.0       39543154.0       35856344.0       30774621.0
# 3          46189.0          51368.0          54849.0          58230.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
unique = ["Albania","Andorra"]
df[df["Country"].isin(unique)]
# Out:
#    Rank CCA3  Country           Capital Continent  2022 Population  \
# 1   138  ALB  Albania            Tirana    Europe        2842321.0
# 4   203  AND  Andorra  Andorra la Vella    Europe          79824.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 1        2866849.0        2882481.0        2913399.0        3182021.0
# 4          77700.0          71746.0          71519.0          66097.0
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# 1        3295066.0        2941651.0        2324731.0     28748.0
# 4          53569.0          35611.0          19860.0       468.0
#
#    Density (per km²)  Growth Rate  World Population Percentage
# 1            98.8702       0.9957                         0.04
# 4           170.5641       1.0100                         0.00

# %%
df[df["Country"].str.contains("United")]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df = df.set_index("Country")

# %%
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df.head(10)
# Out:
#                Country  Rank CCA3           Capital  2022 Population  \
# 0          Afghanistan    36  AFG             Kabul       41128771.0
# 1              Albania   138  ALB            Tirana        2842321.0
# 2              Algeria    34  DZA           Algiers       44903225.0
# 3       American Samoa   213  ASM         Pago Pago          44273.0
# 4              Andorra   203  AND  Andorra la Vella          79824.0
# 5               Angola    42  AGO            Luanda       35588987.0
# 6             Anguilla   224  AIA        The Valley          15857.0
# 7  Antigua and Barbuda   201  ATG      Saint John’s          93763.0
# 8            Argentina    33  ARG      Buenos Aires       45510318.0
# 9              Armenia   140  ARM           Yerevan        2780469.0
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0       38972230.0       33753499.0       28189672.0       19542982.0
# ...

# %%
df.filter(items=["Continent","Country"],axis=1)
# Out:
#                      Country
# Continent
# Asia             Afghanistan
# Europe               Albania
# Africa               Algeria
# Oceania       American Samoa
# Europe               Andorra
# ...                      ...
# Oceania    Wallis and Futuna
# Africa        Western Sahara
# Asia                   Yemen
# Africa                Zambia
# Africa              Zimbabwe
#
# [234 rows x 1 columns]

# %%
df.filter(like="Abu Dhabi",axis=0)
# Out:
# Empty DataFrame
# Columns: [Rank, CCA3, Capital, Continent, 2022 Population, 2020 Population, 2015 Population, 2010 Population, 2000 Population, 1990 Population, 1980 Population, 1970 Population, Area (km²), Density (per km²), Growth Rate, World Population Percentage]
# Index: []

# %%
df.loc["United States"]
# Out:
# Rank                                          3
# CCA3                                        USA
# Capital                        Washington, D.C.
# Continent                         North America
# 2022 Population                     338289857.0
# 2020 Population                     335942003.0
# 2015 Population                     324607776.0
# 2010 Population                     311182845.0
# 2000 Population                     282398554.0
# 1990 Population                     248083732.0
# 1980 Population                     223140018.0
# 1970 Population                     200328340.0
# Area (km²)                            9372610.0
# Density (per km²)                       36.0935
# Growth Rate                              1.0038
# World Population Percentage                4.24
# Name: United States, dtype: object

# %%
df.iloc[2]
# Out:
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# Continent                          Africa
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: Algeria, dtype: object

# %%
df[df["Rank"] < 100].sort_values(by=["Continent","Country"],ascending=(True,True))
# Out:
#                       Rank CCA3           Capital      Continent  \
# Country
# Algeria                 34  DZA           Algiers         Africa
# Angola                  42  AGO            Luanda         Africa
# Benin                   77  BEN        Porto-Novo         Africa
# Burkina Faso            58  BFA       Ouagadougou         Africa
# Burundi                 78  BDI         Bujumbura         Africa
# Cameroon                53  CMR           Yaounde         Africa
# Chad                    69  TCD         N'Djamena         Africa
# DR Congo                15  COD          Kinshasa         Africa
# Egypt                   14  EGY             Cairo         Africa
# Ethiopia                12  ETH       Addis Ababa         Africa
# Ghana                   47  GHA             Accra         Africa
# Guinea                  75  GIN           Conakry         Africa
# Ivory Coast             52  CIV      Yamoussoukro         Africa
# ...
